# %% [markdown]
# 1. Tạo Dataframe như dữ liệu đã cho trên.
# 2. Hiển thị thông tin Dataframe vừa tạo.

# %%
import pandas as pd

data = {
    'Product': ['Laptop', 'Phone', 'Chair', 'Desk', 'Headphone', 'Monitor', 'Sofa', 'Keyboard', 'Mouse', 'Tablet'],
    'Category': ['Electronics', 'Electronics', 'Furniture', 'Furniture', 'Accessories', 'Electronics', 'Furniture', 'Accessories', 'Accessories', 'Electronics'],
    'Price': [1500, 800, 120, 200, 150, 600, 700, 150, 100, 400],
    'Date': ['2024-03-15', '2024-02-20', '2024-03-10', '2024-02-25', '2024-02-08', '2024-02-22', '2024-06-20', '2024-02-08', '2024-03-01', '2024-09-30'],
    'Quantity': [2, 5, 4, 3, 6, 2, 1, 6, 8, 3]
}

df = pd.DataFrame(data)
print(df)
# Out:
#      Product     Category  Price        Date  Quantity
# 0     Laptop  Electronics   1500  2024-03-15         2
# 1      Phone  Electronics    800  2024-02-20         5
# 2      Chair    Furniture    120  2024-03-10         4
# 3       Desk    Furniture    200  2024-02-25         3
# 4  Headphone  Accessories    150  2024-02-08         6
# 5    Monitor  Electronics    600  2024-02-22         2
# 6       Sofa    Furniture    700  2024-06-20         1
# 7   Keyboard  Accessories    150  2024-02-08         6
# 8      Mouse  Accessories    100  2024-03-01         8
# 9     Tablet  Electronics    400  2024-09-30         3

# %% [markdown]
# 3. Tính giá trị trung bình của cột <Price>.

# %%
mean_p = df['Price'].mean()
print("gia tri trung binh ", mean_p)
# Out:
# gia tri trung binh  472.0

# %% [markdown]
# 4.tình tổng trung bình cột <Quantity>

# %%
mean_q = df['Quantity'].mean()
print("gia tri trung binh ", mean_q)
# Out:
# gia tri trung binh  4.0

# %% [markdown]
# 5. Sấp xếp Dataframe theo cột <Price> giảm dần

# %%
df_sorted = df.sort_values(by='Price', ascending=False)
print("sap xep theo Price giam:")
print(df_sorted)
# Out:
# sap xep theo Price giam:
#      Product     Category  Price        Date  Quantity
# 0     Laptop  Electronics   1500  2024-03-15         2
# 1      Phone  Electronics    800  2024-02-20         5
# 6       Sofa    Furniture    700  2024-06-20         1
# 5    Monitor  Electronics    600  2024-02-22         2
# 9     Tablet  Electronics    400  2024-09-30         3
# 3       Desk    Furniture    200  2024-02-25         3
# 7   Keyboard  Accessories    150  2024-02-08         6
# 4  Headphone  Accessories    150  2024-02-08         6
# 2      Chair    Furniture    120  2024-03-10         4
# 8      Mouse  Accessories    100  2024-03-01         8

# %%
import matplotlib.pyplot

# %% [markdown]
# 6. Vẽ biểu đồ cột cho <Price>.

# %%
import matplotlib.pyplot as plt
df['Price'].plot(kind='bar', title='Price')
plt.xlabel('So luong')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# 7.Vẽ biểu đồ phân tán cho <Quantity> và <Price>.

# %%
plt.scatter(df['Quantity'], df['Price'])
plt.title('Phan tan Quantity and Price')
plt.xlabel('Quantity')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# 8. Vẽ biểu đồ đường cho cột <Date>.

# %%
df.plot(x='Date', y='Price', kind='line', title='Line date')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# 9. Vẽ biểu đồ cột thể hiện tổng doanh thu của từng <Category>.

# %%
df['Revenue'] = df['Quantity'] * df['Price']
revenue_category = df.groupby('Category')['Revenue'].sum().reset_index()
revenue_category.plot(x='Category', y='Revenue', kind='bar', title='tong doan thu theo Category')
plt.ylabel('Doanh Thu')
plt.show()

# %% [markdown]
# 10.Kiểm tra có giá trị NaN nào trong DataFrame không.

# %%
nan_check = df.isna().sum()
print("NaN check:")
print(nan_check)
# Out:
# NaN check:
# Product     0
# Category    0
# Price       0
# Date        0
# Quantity    0
# Revenue     0
# dtype: int64

# %% [markdown]
# 11. Tìm các giá trị trùng lặp trong DataFrame dựa trên cột 'Product' và loại bỏ các hàng trùng lặp, giữ lại hàng đầu tiên.

# %%
df = df.drop_duplicates(subset='Product', keep='first')
df
# Out:
#      Product     Category  Price        Date  Quantity  Revenue
# 0     Laptop  Electronics   1500  2024-03-15         2     3000
# 1      Phone  Electronics    800  2024-02-20         5     4000
# 2      Chair    Furniture    120  2024-03-10         4      480
# 3       Desk    Furniture    200  2024-02-25         3      600
# 4  Headphone  Accessories    150  2024-02-08         6      900
# 5    Monitor  Electronics    600  2024-02-22         2     1200
# 6       Sofa    Furniture    700  2024-06-20         1      700
# 7   Keyboard  Accessories    150  2024-02-08         6      900
# 8      Mouse  Accessories    100  2024-03-01         8      800
# 9     Tablet  Electronics    400  2024-09-30         3     1200

# %% [markdown]
# 12. Lọc ra các đơn hàng có số lượng (Quantity) lớn hơn 5

# %%
loc_orders = df[df['Quantity'] > 5]
print("loc don hang lon hon 5")
print(loc_orders)
# Out:
# loc don hang lon hon 5
#      Product     Category  Price        Date  Quantity  Revenue
# 4  Headphone  Accessories    150  2024-02-08         6      900
# 7   Keyboard  Accessories    150  2024-02-08         6      900
# 8      Mouse  Accessories    100  2024-03-01         8      800

# %% [markdown]
# 13. Tổng doanh thu

# %%
df['Revenue'] = df['Quantity'] * df['Price']
df
# Out:
#      Product     Category  Price        Date  Quantity  Revenue
# 0     Laptop  Electronics   1500  2024-03-15         2     3000
# 1      Phone  Electronics    800  2024-02-20         5     4000
# 2      Chair    Furniture    120  2024-03-10         4      480
# 3       Desk    Furniture    200  2024-02-25         3      600
# 4  Headphone  Accessories    150  2024-02-08         6      900
# 5    Monitor  Electronics    600  2024-02-22         2     1200
# 6       Sofa    Furniture    700  2024-06-20         1      700
# 7   Keyboard  Accessories    150  2024-02-08         6      900
# 8      Mouse  Accessories    100  2024-03-01         8      800
# 9     Tablet  Electronics    400  2024-09-30         3     1200

# %% [markdown]
# 14. Thêm một cột <Sales_Level> với điều kiện:
# + < 500 ->> Low
# + 500 --- 2000 ->> Medium
# + >2000 ->> High

# %%
def sales_level(revenue):
    if revenue < 500:
        return 'Low'
    elif 500 <= revenue <= 2000:
        return 'Medium'
    else:
        return 'High'
df['Sales_Level'] = df['Revenue'].apply(sales_level)
df
# Out:
#      Product     Category  Price        Date  Quantity  Revenue Sales_Level
# 0     Laptop  Electronics   1500  2024-03-15         2     3000        High
# 1      Phone  Electronics    800  2024-02-20         5     4000        High
# 2      Chair    Furniture    120  2024-03-10         4      480         Low
# 3       Desk    Furniture    200  2024-02-25         3      600      Medium
# 4  Headphone  Accessories    150  2024-02-08         6      900      Medium
# 5    Monitor  Electronics    600  2024-02-22         2     1200      Medium
# 6       Sofa    Furniture    700  2024-06-20         1      700      Medium
# 7   Keyboard  Accessories    150  2024-02-08         6      900      Medium
# 8      Mouse  Accessories    100  2024-03-01         8      800      Medium
# 9     Tablet  Electronics    400  2024-09-30         3     1200      Medium

# %% [markdown]
# 15. Vẽ biểu đồ cột thể hiện số lượng đơn hàng ở từng mức <Sales_Level>.

# %%
sales_level_count = df['Sales_Level'].value_counts()
sales_level_count.plot(kind='bar', title='Sl don hang theo Sales Level')
plt.ylabel('sl don hang')
plt.show()

# %% [markdown]
# 16. Tạo một cột mới <Discount> với giá trị giảm giá 10% nếu doanh thu (Revenue) > 1000, ngược lại giảm giá 5%.

# %%
df['Discount'] = df['Revenue'].apply(lambda x: 0.10 if x > 1000 else 0.05)
df
# Out:
#      Product     Category  Price        Date  Quantity  Revenue Sales_Level  \
# 0     Laptop  Electronics   1500  2024-03-15         2     3000        High
# 1      Phone  Electronics    800  2024-02-20         5     4000        High
# 2      Chair    Furniture    120  2024-03-10         4      480         Low
# 3       Desk    Furniture    200  2024-02-25         3      600      Medium
# 4  Headphone  Accessories    150  2024-02-08         6      900      Medium
# 5    Monitor  Electronics    600  2024-02-22         2     1200      Medium
# 6       Sofa    Furniture    700  2024-06-20         1      700      Medium
# 7   Keyboard  Accessories    150  2024-02-08         6      900      Medium
# 8      Mouse  Accessories    100  2024-03-01         8      800      Medium
# 9     Tablet  Electronics    400  2024-09-30         3     1200      Medium
#
#    Discount
# 0      0.10
# 1      0.10
# 2      0.05
# 3      0.05
# 4      0.05
# 5      0.10
# 6      0.05
# 7      0.05
# 8      0.05
# 9      0.10

# %% [markdown]
# 17. Tính doanh thu sau giảm giá <Final_Revenue> bằng công thức:
# Final_Revenue = Revenue - ( Revenue ×Discount ).

# %%
df['Final_Revenue'] = df['Revenue'] - (df['Revenue'] * df['Discount'])
df
# Out:
#      Product     Category  Price        Date  Quantity  Revenue Sales_Level  \
# 0     Laptop  Electronics   1500  2024-03-15         2     3000        High
# 1      Phone  Electronics    800  2024-02-20         5     4000        High
# 2      Chair    Furniture    120  2024-03-10         4      480         Low
# 3       Desk    Furniture    200  2024-02-25         3      600      Medium
# 4  Headphone  Accessories    150  2024-02-08         6      900      Medium
# 5    Monitor  Electronics    600  2024-02-22         2     1200      Medium
# 6       Sofa    Furniture    700  2024-06-20         1      700      Medium
# 7   Keyboard  Accessories    150  2024-02-08         6      900      Medium
# 8      Mouse  Accessories    100  2024-03-01         8      800      Medium
# 9     Tablet  Electronics    400  2024-09-30         3     1200      Medium
#
#    Discount  Final_Revenue
# 0      0.10         2700.0
# 1      0.10         3600.0
# 2      0.05          456.0
# 3      0.05          570.0
# 4      0.05          855.0
# 5      0.10         1080.0
# 6      0.05          665.0
# 7      0.05          855.0
# 8      0.05          760.0
# 9      0.10         1080.0

# %% [markdown]
# 18. Tạo cột <Month> lấy giá trị tháng từ cột <Date>.

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month
df
# Out:
#      Product     Category  Price       Date  Quantity  Revenue Sales_Level  \
# 0     Laptop  Electronics   1500 2024-03-15         2     3000        High
# 1      Phone  Electronics    800 2024-02-20         5     4000        High
# 2      Chair    Furniture    120 2024-03-10         4      480         Low
# 3       Desk    Furniture    200 2024-02-25         3      600      Medium
# 4  Headphone  Accessories    150 2024-02-08         6      900      Medium
# 5    Monitor  Electronics    600 2024-02-22         2     1200      Medium
# 6       Sofa    Furniture    700 2024-06-20         1      700      Medium
# 7   Keyboard  Accessories    150 2024-02-08         6      900      Medium
# 8      Mouse  Accessories    100 2024-03-01         8      800      Medium
# 9     Tablet  Electronics    400 2024-09-30         3     1200      Medium
#
#    Discount  Final_Revenue  Month
# 0      0.10         2700.0      3
# 1      0.10         3600.0      2
# 2      0.05          456.0      3
# 3      0.05          570.0      2
# 4      0.05          855.0      2
# 5      0.10         1080.0      2
# 6      0.05          665.0      6
# 7      0.05          855.0      2
# 8      0.05          760.0      3
# 9      0.10         1080.0      9

# %% [markdown]
# 19. Vẽ biểu đồ đường thể hiện tổng doanh thu theo tháng.

# %%
monthly_revenue = df.groupby('Month')['Final_Revenue'].sum().reset_index()
monthly_revenue.plot(x='Month', y='Final_Revenue', kind='line', title='tong doanh thu theo thangthang')
plt.ylabel('Doanh Thu')
plt.show()

# %% [markdown]
# 20. Lưu DataFrame với tên <BKT_MSSV_Hoten.csv-->

# %%
df.to_csv('BKT_MSSV_Hoten.csv', index=False)
print("Đã lưu DataFrame vào file BKT_MSSV_Hoten.csv")
# Out:
# Đã lưu DataFrame vào file BKT_MSSV_Hoten.csv
